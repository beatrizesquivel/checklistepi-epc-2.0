# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizesquivel/checklistepi-epc-2.0/blob/main/SEGURAN%C3%87A_DO_TRABALHO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Checklist dos equipamentos de segurança:
def obter_equipamentos(atividade):
    atividade = atividade.lower()

        # Verifica se a atividade é do carpinteiro ou do seu auxiliar
    if "carpinteiro" in atividade:
        return {
            "EPIs": [ # Equipamentos de proteçâo individual
                "👷‍♂️🔨",
                "Capacete de segurança",
                "Cinto de segurança tipo paraquedista",
                "Botina com bico de aço",
                "Luvas de proteção",
                "Óculos de proteção"
            ],
            "EPCs": [ # Equipamentos de proteção coletiva
                "Linha de vida",
                "Rede de proteção",
                "Placas de sinalização de risco"
          ]
            } # Verifica se a atividade é do pedreiro ou do seu auxiliar
    elif "pedreiro" in atividade:
        return {
            "EPIs": [
                "🚧",
                "Capacete",
                "Botina com bico de aço",
                "Luvas de proteção",
                "Óculos de proteção"
            ],
            "EPCs": [
                "Barreiras de isolamento da área",
                "Placas de sinalização"
         ]
            } # Verifica se a atividade é do eletricista ou do seu auxiliar
    elif "eletricista" in atividade:
       return {
            "EPIs": [
                "👷💡",
                "Luvas isolantes",
                "Botina dielétrica",
                "Capacete com proteção facial",
                "Óculos de proteção"
            ],
            "EPCs": [
                "Sistema de bloqueio e etiquetagem",
                "Desenergização da rede",
                "Sinalização de área"
          ]
            } # Verifica se a atividade é do soldador ou do seu auxiliar
    elif "soldador" " ajudante de " in atividade:
        return {
            "EPIs": [
                "👷‍♂️🧤",
                "Máscara de solda",
                "Luvas de vaqueta",
                "Avental de couro",
                "Botina com bico de aço",
                "Protetor auricular"
            ],
            "EPCs": [
                "Cortina de solda",
                "Ventilação do ambiente",
                "Extintor de incêndio por perto"
          ]
            } # Verifica se a atividade é do armador ou do seu auxiliar
    elif "armador" in atividade:
        return {
        "EPIs": [
            "👷‍♂️🔩",
            "Capacete de segurança",
            "Luvas de vaqueta",
            "Botina com bico de aço",
            "Óculos de proteção",
        ],
        "EPCs": [
            "Organização do canteiro",
            "Placas de sinalização",
            "Proteção contra quedas de objetos"
        ]
        } # Verifica se a atividade é do encanador ou do seu auxiliar
    elif "encanador" in atividade:
        return {
        "EPIs": [
                "👷‍♂️🚿",
               "Capacete de segurança",
               "Luvas de borracha",
               "Botina impermeável",
               "Máscara descartável",
               "Óculos de proteção"
        ],
        "EPCs": [
              "Ventilação adequada",
              "Placas de sinalização",
              "Organização do material"
         ]
        }
    else:
        return {
            "EPIs": ["Verificar atividade para definir EPIs específicos"],
            "EPCs": ["Verificar atividade para definir EPCs específicos"]
        }

# Programa principal
print("CHECKLIST DE EPIs e EPCs PARA OBRA")
atividade = input("Informe qual a sua atribuição na obra: ") # Solicita ao usuário o setor onde irá trabalhar na obra

equipamentos = obter_equipamentos(atividade) #Chama a função para obter os equipamentos com base na atividade

print("\n EPIs necessários") # Exibe os EPIs necessário
for epi in equipamentos["EPIs"]:
    print(f"- {epi}")

print("\n EPCs necessários") # Exibe os EPCs necessários
for epc in equipamentos["EPCs"]:
    print(f"- {epc}")

print("SUA SEGURANÇA EM PRIMEIRO LUGAR⛑️") # Mensagem reforçando a segurança
# Out:
# CHECKLIST DE EPIs e EPCs PARA OBRA

# %%
def obter_equipamentos(atividade):
    atividade = atividade.lower()

    atividades_data = {
        "carpinteiro": {
            "EPIs": [
                "👷‍♂️🔨", "Capacete de segurança", "Cinto de segurança tipo paraquedista",
                "Botina com bico de aço", "Luvas de proteção", "Óculos de proteção"
            ],
            "EPCs": [
                "Linha de vida", "Rede de proteção", "Placas de sinalização de risco"
            ]
        },
        "pedreiro": {
            "EPIs": [
                "🚧", "Capacete", "Botina com bico de aço",
                "Luvas de proteção", "Óculos de proteção"
            ],
            "EPCs": [
                "Barreiras de isolamento da área", "Placas de sinalização"
            ]
        },
        "eletricista": {
            "EPIs": [
                "👷💡", "Luvas isolantes", "Botina dielétrica",
                "Capacete com proteção facial", "Óculos de proteção"
            ],
            "EPCs": [
                "Sistema de bloqueio e etiquetagem", "Desenergização da rede", "Sinalização de área"
            ]
        },
        "soldador": {
            "EPIs": [
                "👷‍♂️🧤", "Máscara de solda", "Luvas de vaqueta", "Avental de couro",
                "Botina com bico de aço", "Protetor auricular"
            ],
            "EPCs": [
                "Cortina de solda", "Ventilação do ambiente", "Extintor de incêndio por perto"
            ]
        },
        "armador": {
            "EPIs": [
                "👷‍♂️🔩", "Capacete de segurança", "Luvas de vaqueta",
                "Botina com bico de aço", "Óculos de proteção",
            ],
            "EPCs": [
                "Organização do canteiro", "Placas de sinalização", "Proteção contra quedas de objetos"
            ]
        },
        "encanador": {
            "EPIs": [
                "👷‍♂️🚿", "Capacete de segurança", "Luvas de borracha",
                "Botina impermeável", "Máscara descartável", "Óculos de proteção"
            ],
            "EPCs": [
                "Ventilação adequada", "Placas de sinalização", "Organização do material"
            ]
        }
    }

    # Verifica se a atividade exata está no dicionário
    if atividade in atividades_data:
        return atividades_data[atividade]
    # Se a atividade exata não for encontrada, tenta verificar se é um "auxiliar de"
    for key in atividades_data:
        if f"auxiliar de {key}" in atividade:
            return atividades_data[key]

    return {
        "EPIs": ["Verificar atividade para definir EPIs específicos"],
        "EPCs": ["Verificar atividade para definir EPCs específicos"]
    }

# %%
# EPIs e EPCs gerais
EPIS = {
    "capacete": "Capacete de segurança",
    "botina_aco": "Botina com bico de aço",
    "luvas_protecao": "Luvas de proteção",
    "oculos": "Óculos de proteção",
    "mascara_desc": "Máscara descartável",
    "luvas_borracha": "Luvas de borracha",
    "luvas_vaqueta": "Luvas de vaqueta",
    "cinto": "Cinto de segurança tipo paraquedista",
    "mascara_solda": "Máscara de solda",
    "botina_dieletrica": "Botina dielétrica",
    "protetor_auricular": "Protetor auricular",
}

EPCS = {
    "sinalizacao": "Placas de sinalização",
    "rede": "Rede de proteção",
    "linha_vida": "Linha de vida",
    "isolamento": "Barreiras de isolamento da área",
    "desenergizacao": "Desenergização da rede",
    "ventilacao": "Ventilação do ambiente",
    "organizacao": "Organização do canteiro ou do material",
    "bloqueio": "Sistema de bloqueio e etiquetagem",
    "extintor": "Extintor de incêndio por perto"
}

# Dados por profissão
FUNCOES = {
    "carpinteiro": {
        "emoji": "👷‍♂️🔨",
        "epis": ["capacete", "cinto", "botina_aco", "luvas_protecao", "oculos"],
        "epcs": ["linha_vida", "rede", "sinalizacao"]
    },
    "pedreiro": {
        "emoji": "🚧",
        "epis": ["capacete", "botina_aco", "luvas_protecao", "oculos"],
        "epcs": ["isolamento", "sinalizacao"]
    },
    "eletricista": {
        "emoji": "👷💡",
        "epis": ["luvas_borracha", "botina_dieletrica", "capacete", "oculos"],
        "epcs": ["bloqueio", "desenergizacao", "sinalizacao"]
    },
    "soldador": {
        "emoji": "👷‍♂️🧤",
        "epis": ["mascara_solda", "luvas_vaqueta", "botina_aco", "protetor_auricular"],
        "epcs": ["ventilacao", "sinalizacao", "extintor"]
    },
    "armador": {
        "emoji": "👷‍♂️🔩",
        "epis": ["capacete", "luvas_vaqueta", "botina_aco", "oculos"],
        "epcs": ["organizacao", "sinalizacao", "rede"]
    },
    "encanador": {
        "emoji": "👷‍♂️🚿",
        "epis": ["capacete", "luvas_borracha", "botina_aco", "mascara_desc", "oculos"],
        "epcs": ["ventilacao", "sinalizacao", "organizacao"]
    }
}

# Classe
class Trabalhador:
    def __init__(self, atividade):
        self.atividade = atividade.lower()

    def obter_equipamentos(self):
        for funcao, dados in FUNCOES.items():
            if funcao in self.atividade:
                epis = [dados["emoji"]] + [EPIS.get(e, e) for e in dados["epis"]]
                epcs = [EPCS.get(e, e) for e in dados["epcs"]]
                return {"EPIs": epis, "EPCs": epcs}
        return {
            "EPIs": ["Verificar atividade para definir EPIs específicos"],
            "EPCs": ["Verificar atividade para definir EPCs específicos"]
        }

# Programa principal
print("CHECKLIST DE EPIs e EPCs PARA OBRA")
atividade = input("Informe sua atribuição na obra: ")
trabalhador = Trabalhador(atividade)
equip = trabalhador.obter_equipamentos()

print("\nEPIs necessários:")
print('\n'.join(f"- {epi}" for epi in equip["EPIs"]))

print("\nEPCs necessários:")
print('\n'.join(f"- {epc}" for epc in equip["EPCs"]))

print("\nSUA SEGURANÇA EM PRIMEIRO LUGAR⛑️")
# Out:
# CHECKLIST DE EPIs e EPCs PARA OBRA
# Informe sua atribuição na obra: encanador
#
# EPIs necessários:
# - 👷‍♂️🚿
# - Capacete de segurança
# - Luvas de borracha
# - Botina com bico de aço
# - Máscara descartável
# - Óculos de proteção
#
# EPCs necessários:
# - Ventilação do ambiente
# - Placas de sinalização
# - Organização do canteiro ou do material
#
# SUA SEGURANÇA EM PRIMEIRO LUGAR⛑️

# %%
# Testando várias funções na obra
atividades_teste = [
    "carpinteiro",
    "pedreiro",
    "eletricista",
    "soldador",
    "armador",
    "encanador",
    "ajudante de pedreiro",  # também funciona
    "engenheiro"             # esse vai cair no else
]

for atividade in atividades_teste:
    print("\n==============================")
    print(f"Atividade: {atividade.upper()}")
    equipamentos = obter_equipamentos(atividade)

    print("\n EPIs necessários")
    for epi in equipamentos["EPIs"]:
        print(f"- {epi}")

    print("\n EPCs necessários")
    for epc in equipamentos["EPCs"]:
        print(f"- {epc}")

print("\nTESTES FINALIZADOS ✅")
# Out:
# ...
# Atividade: CARPINTEIRO
#
#  EPIs necessários
# - 👷‍♂️🔨
# - Capacete de segurança
# - Cinto de segurança tipo paraquedista
# - Botina com bico de aço
# - Luvas de proteção
# - Óculos de proteção
#
#  EPCs necessários
# - Linha de vida
# - Rede de proteção
# - Placas de sinalização de risco
#
# ...
# Atividade: PEDREIRO
#
#  EPIs necessários
# - 🚧
# - Capacete
# - Botina com bico de aço
# - Luvas de proteção
# - Óculos de proteção
#
#  EPCs necessários
# - Barreiras de isolamento da área
# - Placas de sinalização
#
# ...
# Atividade: ELETRICISTA
#
#  EPIs necessários
# - 👷💡
# - Luvas isolantes
# - Botina dielétrica
# - Capacete com proteção facial
# - Óculos de proteção
#
#  EPCs necessários
# - Sistema de bloqueio e etiquetagem
# - Desenergização da rede
# - Sinalização de área
#
# ...
# Atividade: SOLDADOR
#
#  EPIs necessários
# - 👷‍♂️🧤
# - Máscara de solda
# - Luvas de vaqueta
# - Avental de couro
# - Botina com bico de aço
# - Protetor auricular
#
#  EPCs necessários
# - Cortina de solda
# ...
